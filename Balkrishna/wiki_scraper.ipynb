# %%
import wikipediaapi
import csv
from collections import deque

def wikipedia_scrap():
    gu_wiki = wikipediaapi.Wikipedia(
        user_agent="GujaratiScraperBot",
        language='gu',
        extract_format=wikipediaapi.ExtractFormat.WIKI
    )
    counter = 0
    visited_links = set()
    page_queue = deque()  # Queue for iterative scraping when recursion depth is reached

    # Function to scrape a page and its links with recursion limit handling
    def scrape_page(page_title, writer):
        nonlocal counter
        if page_title in visited_links:
            return
        visited_links.add(page_title)

        try:
            page = gu_wiki.page(page_title)
            if not page.exists() or len(page.text) == 0:
                return

            # Write the page data to CSV
            writer.writerow({
                'URL': page.fullurl,
                'DATA': page.text
            })
            counter += 1
            print(f"Page {page_title} scraped, Count: {counter}")

            # Recursively scrape links
            for link_title in page.links.keys():
                scrape_page(link_title, writer)
        except RecursionError:
            print(f"Recursion limit reached while scraping {page_title}. Switching to iteration.")
            # If recursion limit is reached, add remaining links to the queue for iterative processing
            for link_title in page.links.keys():
                if link_title not in visited_links:
                    page_queue.append(link_title)
        except Exception as e:
            print(f"Some exception occured : {e}")
            return

    # Function to scrape pages iteratively (fallback after recursion limit)
    def scrape_page_iteratively(writer):
        nonlocal counter
        while page_queue:
            try:
                page_title = page_queue.popleft()
                if page_title in visited_links:
                    continue
                visited_links.add(page_title)

                page = gu_wiki.page(page_title)
            
                if not page.exists() or len(page.text) == 0:
                    continue
            except Exception as e:
                print(f"Some exception occured : {e}")
                continue
            
            # Write the page data to CSV
            writer.writerow({
                'URL': page.fullurl,
                'DATA': page.text
            })
            counter += 1
            print(f"Page {page_title} scraped, Count: {counter}")

            # Add links from the current page to the queue
            for link_title in page.links.keys():
                if link_title not in visited_links:
                    page_queue.append(link_title)

    # Main scraping logic
    with open('gujarati_wiki_scraped.csv', 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['URL', 'DATA']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Start with the initial page
        start_page_title = "પાયથોન(પ્રોગ્રામિંગ_ભાષા)"
        scrape_page(start_page_title, writer)

        # If recursion limit was reached, continue with iterative scraping
        scrape_page_iteratively(writer)

    print(f"Data has been saved to gujarati_wiki_scraped.csv")

# Call the function to scrape pages
wikipedia_scrap()
# Out:
# Page પાયથોન(પ્રોગ્રામિંગ_ભાષા) scraped, Count: 1
# Page C++(પ્રોગ્રામિંગ ભાષા) scraped, Count: 2
# Page C (પ્રોગ્રામિંગ ભાષા) scraped, Count: 3
# Page C શાર્પ (પ્રોગ્રામિંગ ભાષા) scraped, Count: 4
# Page IP એડ્રેસ scraped, Count: 5
# Page IPv4 scraped, Count: 6
# Page Hypertext Transfer Protocol scraped, Count: 7
# Page HTML scraped, Count: 8
# Page ઇન્ટરનેટ scraped, Count: 9
# Page ISBN (identifier) scraped, Count: 10
# Page ઇન્ટરનેશનલ સ્ટાન્ડર્ડ સિરિયલ નંબર scraped, Count: 11
# Page ઇન્ટરનેશનલ સ્ટાન્ડર્ડ બુક નંબર scraped, Count: 12
# Page ઢાંચાની ચર્ચા:સ્ટબ scraped, Count: 13
# Page સભ્ય:Dsvyas scraped, Count: 14
# Page અંગ્રેજી ભાષા scraped, Count: 15
# Page ઇંગ્લેન્ડ scraped, Count: 16
# Page અફઘાનિસ્તાન scraped, Count: 17
# Page ઈરાન scraped, Count: 18
# Page અક્રોતીરી અને ધેકેલીયા scraped, Count: 19
# Page અંગ્રેજી scraped, Count: 20
# Page ઓસ્ટ્રેલિયા scraped, Count: 21
# Page એડિલેઇડ scraped, Count: 22
# Page ઑસ્ટ્રેલિયા scraped, Count: 23
# Page ક્વીન્સલેન્ડ scraped, Count: 24
# Page ક્રિકેટ scraped, Count: 25
# Page ઈસ્ટોનિયા scraped, Count: 26
# Page અઝેરબીજાન scraped, Count: 27
# Page આઈસલેંડ scraped, Count: 28
# Page આયરલેંડનું ગણતંત્ર scraped, Count: 29
# Page આર્મેનિયા scraped, Count: 30
# Page ગુજરાતી વિશ્વકોશ scraped, Count: 31
# Page ગુજરાત યુનિવર્સિટી scraped, Count: 32
# Page અમદાવાદ scraped, Count: 33
# Page UTC+૫:૩૦ scraped, Count: 34
# Page ભારત scraped, Count: 35
# Page અંદામાન અને નિકોબાર દ્વીપસમૂહ scraped, Count: 36
# Page અંદામાન અને નિકોબાર કમાન્ડ scraped, Count: 37
# Page ISSN (identifier) scraped, Count: 38
# Page પેરિસ scraped, Count: 39
# Page ઍફીલ ટાવર scraped, Count: 40
# Page ચીન scraped, Count: 41
# Page કન્ફયુસીયસ ધર્મ scraped, Count: 42
# Page ઇતિહાસ scraped, Count: 43
# Page વેદ scraped, Count: 44
# Page અથર્વવેદ scraped, Count: 45
# Page અગ્નિ scraped, Count: 46
# Page આયુર્વેદ scraped, Count: 47
# Page અગ્નિવેશ scraped, Count: 48
# Page અગસ્ત્ય scraped, Count: 49
# Page અક્ષયકુમાર (રામાયણ) scraped, Count: 50
# Page અતિકાયા scraped, Count: 51
# Page અયોધ્યા scraped, Count: 52
# Page TV9 ગુજરાત scraped, Count: 53
# Page કલર્સ ગુજરાતી scraped, Count: 54
# Page ડીડી ગિરનાર scraped, Count: 55
# Page ગુજરાત scraped, Count: 56
# Page અંકલેશ્વર scraped, Count: 57
# Page અંકલેશ્વર તાલુકો scraped, Count: 58
# Page અંદાડા scraped, Count: 59
# Page અક્ષાંશ-રેખાંશ scraped, Count: 60
# Page ઉત્તર scraped, Count: 61
# Page દક્ષિણ scraped, Count: 62
# Page પશ્ચિમ scraped, Count: 63
# Page ક્રિયાવિશેષણ scraped, Count: 64
# Page શ્રેણી:લેખ જેમાં થી સુધારાની જરુર છે scraped, Count: 65
# Page પૂર્વ scraped, Count: 66
# Page ભૂગોળ scraped, Count: 67
# Page પૃથ્વી scraped, Count: 68
# Page આકાશગંગા scraped, Count: 69
# Page સ્ટબ scraped, Count: 70
# Page મહાત્મા ગાંધી scraped, Count: 71
# Page International Standard Book Number scraped, Count: 72
# Page અનુશીલન સમિતિ scraped, Count: 73
# Page અંબાડી (હાથી) scraped, Count: 74
# Page હાથી scraped, Count: 75
# Page અબુલ કલામ આઝાદ scraped, Count: 76
# Page અટલ બિહારી વાજપેયી scraped, Count: 77
# Page અબ્દુલ કલામ scraped, Count: 78
# Page અમર્ત્ય સેન scraped, Count: 79
# Page એશિયા scraped, Count: 80
# Page આફ્રિકા scraped, Count: 81
# Page અંગોલાનો રાષ્ટ્રધ્વજ scraped, Count: 82
# Page એરિટ્રિયાનો રાષ્ટ્રધ્વજ scraped, Count: 83
# Page રક્ત scraped, Count: 84
# Page કુપોષણ scraped, Count: 85
# Page ઈરાક scraped, Count: 86
# Page અરબી ભાષા scraped, Count: 87
# Page ISO 639-2 scraped, Count: 88
# Page વેબેક મશિન scraped, Count: 89
# Page કેલિફોર્નિયા scraped, Count: 90
# Page મેક્સિકો scraped, Count: 91
# Page સંયુક્ત રાજ્ય અમેરિકા scraped, Count: 92
# Page અબ્રાહમ લિંકન scraped, Count: 93
# Page OCLC (identifier) scraped, Count: 94
# Page એપ્રિલ ૧૫ scraped, Count: 95
# Page અમેરિકા scraped, Count: 96
# Page આર્જેન્ટીના scraped, Count: 97
# Page ઘઉં scraped, Count: 98
# Page ખાંડ scraped, Count: 99
# Page ગુજરાત રાજ્ય સહકારી ખાંડ ઉદ્યોગ સંઘ લિમિટેડ scraped, Count: 100
# Page ઓલપાડ scraped, Count: 101
# Page આંગણવાડી scraped, Count: 102
# Page ઓલપાડ તાલુકો scraped, Count: 103
# Page અંભેટા (ઓલપાડ) scraped, Count: 104
# Page ખેતમજૂરી scraped, Count: 105
# Page ખેતર scraped, Count: 106
# Page સ્પેન scraped, Count: 107
# Page કેનેરી ટાપુઓ scraped, Count: 108
# Page એટલાન્ટિક મહાસાગર scraped, Count: 109
# Page આર્કટિક મહાસાગર scraped, Count: 110
# Page કેનેડા scraped, Count: 111
# Page જુલાઇ ૧ scraped, Count: 112
# Page અબ્દુલ હમીદ scraped, Count: 113
# Page અમૃતસર scraped, Count: 114
# Page અમૃતસર જિલ્લો scraped, Count: 115
# Page કપૂરથલા જિલ્લો scraped, Count: 116
# Page કપૂરથલા scraped, Count: 117
# Page ગુરદાસપુર જિલ્લો scraped, Count: 118
# Page ગુરદાસપુર scraped, Count: 119
# Page જલંધર જિલ્લો scraped, Count: 120
# Page જલંધર scraped, Count: 121
# Page તરન તારન સાહિબ જિલ્લો scraped, Count: 122
# Page તરન તારન સાહિબ scraped, Count: 123
# Page નવા શહર જિલ્લો scraped, Count: 124
# Page નવા શહર scraped, Count: 125
# Page પંજાબ scraped, Count: 126
# Page કાશ્મીર scraped, Count: 127
# Page અનંતનાગ scraped, Count: 128
# Page અનંતનાગ જિલ્લો scraped, Count: 129
# Page Geographic coordinate system scraped, Count: 130
# Page ઉત્તર ધ્રુવ scraped, Count: 131
# Page જમ્મુ અને કાશ્મીર scraped, Count: 132
# Page અમરનાથ (તીર્થધામ) scraped, Count: 133
# Page અષાઢ સુદ ૧૫ scraped, Count: 134
# Page અધિક માસ scraped, Count: 135
# Page ચૈત્ર scraped, Count: 136
# Page અષાઢ scraped, Count: 137
# Page આસામ scraped, Count: 138
# Page અરુણાચલ પ્રદેશ scraped, Count: 139
# Page અંજા જિલ્લો scraped, Count: 140
# Page ઉપરી દિબાંગ ઘાટી જિલ્લો scraped, Count: 141
# Page અનીની scraped, Count: 142
# Page ઉપરી સિયાંગ જિલ્લો scraped, Count: 143
# Page ઉપરી સુબનસિરી જિલ્લો scraped, Count: 144
# Page કુરુંગ કુમે જિલ્લો scraped, Count: 145
# Page કોલોરીયાંગ scraped, Count: 146
# Page ચેંગલોન્ગ જિલ્લો scraped, Count: 147
# Page ચેંગલોન્ગ scraped, Count: 148
# Page તવાંગ જિલ્લો scraped, Count: 149
# Page તવાંગ scraped, Count: 150
# Page ગુવાહટી scraped, Count: 151
# Page આસામી ભાષા scraped, Count: 152
# Page ભૂતાન scraped, Count: 153
# Page ઇજિપ્ત scraped, Count: 154
# Page કૈરો scraped, Count: 155
# Page સમય વિસ્તાર scraped, Count: 156
# Page ભારતીય માનક સમય scraped, Count: 157
# Page અલ્હાબાદ scraped, Count: 158
# Page અલ્હાબાદ જિલ્લો scraped, Count: 159
# Page અમરોહા જિલ્લો scraped, Count: 160
# Page અમરોહા scraped, Count: 161
# Page ઉત્તર પ્રદેશ scraped, Count: 162
# Page અમેઠી જિલ્લો scraped, Count: 163
# Page અયોધ્યા જિલ્લો scraped, Count: 164
# Page અયોધ્યા પ્રાંત scraped, Count: 165
# Page અલીગઢ પ્રાંત scraped, Count: 166
# Page અલીગઢ જિલ્લો scraped, Count: 167
# Page અલીગઢ scraped, Count: 168
# Page આંબેડકર નગર જિલ્લો scraped, Count: 169
# Page અકબરપુર scraped, Count: 170
# Page કાનપુર દેહાત જિલ્લો scraped, Count: 171
# Page આગ્રા જિલ્લો scraped, Count: 172
# Page આગ્રા scraped, Count: 173
# Page આસનસોલ scraped, Count: 174
# Page ઓરિસ્સા scraped, Count: 175
# Page અનુગુલ જિલ્લો scraped, Count: 176
# Page ઑડિશા scraped, Count: 177
# Page અશોક scraped, Count: 178
# Page ગીરનાર scraped, Count: 179
# Page અંબિકા scraped, Count: 180
# Page અંબા (પૌરાણિક પાત્ર) scraped, Count: 181
# Page અંબાલિકા scraped, Count: 182
# Page અક્ષૌહિણી scraped, Count: 183
# Page અધિરથ scraped, Count: 184
# Page અભિમન્યુ scraped, Count: 185
# Page અર્જુન scraped, Count: 186
# Page અશ્વત્થામા scraped, Count: 187
# Page અહિલાવતી scraped, Count: 188
# Page આદિપર્વ scraped, Count: 189
# Page આરણ્યકપર્વ scraped, Count: 190
# Page ઇન્દ્ર scraped, Count: 191
# Page સંસ્કૃત ભાષા scraped, Count: 192
# Page ઉડિયા ભાષા scraped, Count: 193
# Page આંધ્ર પ્રદેશ scraped, Count: 194
# Page અદિલાબાદ જિલ્લો scraped, Count: 195
# Page કરીમનગર જિલ્લો scraped, Count: 196
# Page ખમ્મમ જિલ્લો scraped, Count: 197
# Page ખમ્મમ scraped, Count: 198
# Page ઉર્દૂ ભાષા scraped, Count: 199
# Page ખડી હિંદી બોલી scraped, Count: 200
# Page અંબાલા scraped, Count: 201
# Page અંબાલા જિલ્લો scraped, Count: 202
# Page કરનાલ જિલ્લો scraped, Count: 203
# Page કરનાલ scraped, Count: 204
# Page કર્ણ તળાવ scraped, Count: 205
# Page કર્ણ scraped, Count: 206
# Page ઇન્દ્રપ્રસ્થ scraped, Count: 207
# Page ઇરવન scraped, Count: 208
# Page ઉત્તરા scraped, Count: 209
# Page ઉદ્યોગપર્વ scraped, Count: 210
# Page આદિ શંકરાચાર્ય scraped, Count: 211
# Page અદ્વૈત વેદાંત scraped, Count: 212
# Page અદ્વૈત વેદાંતના આચાર્યોની યાદી scraped, Count: 213
# Page અંગિરસ scraped, Count: 214
# Page અથર્વ ઋષિ scraped, Count: 215
# Page કર્દમ scraped, Count: 216
# Page અંગિરા scraped, Count: 217
# Page ઋગ્વેદ scraped, Count: 218
# Page ઉપનિષદ scraped, Count: 219
# Page ગીતા scraped, Count: 220
# Page અક્ષરબ્રહ્મ યોગ scraped, Count: 221
# Page અર્જુનવિષાદ યોગ scraped, Count: 222
# Page આત્મસંયમ યોગ scraped, Count: 223
# Page કર્મ યોગ scraped, Count: 224
# Page કર્મસંન્યાસ યોગ scraped, Count: 225
# Page જ્ઞાનકર્મસંન્યાસ યોગ scraped, Count: 226
# Page જ્ઞાનવિજ્ઞાન યોગ scraped, Count: 227
# Page દેવાસુરસંપદ્વિભાગ યોગ scraped, Count: 228
# Page પુરુષોત્તમ યોગ scraped, Count: 229
# Page શ્રીમદ્ ભગવદ્ ગીતા scraped, Count: 230
# Page અબ્બાસ તૈયબજી scraped, Count: 231
# Page અસહકારની ચળવળ scraped, Count: 232
# Page આઝાદ હિંદ ફોજ scraped, Count: 233
# Page આર્ય સમાજ scraped, Count: 234
# Page કાકોરી કાંડ scraped, Count: 235
# Page અશફાક ઊલ્લા ખાન scraped, Count: 236
# Page કુરાન scraped, Count: 237
# Page અલ્લાહ scraped, Count: 238
# Page ઇસ્લામ scraped, Count: 239
# Page ઇસ્લામના પયગંબરો scraped, Count: 240
# Some exception occured : 'pages'
# Page ઇસ્લામીક પંચાંગ scraped, Count: 241
# Page ગુરુવાર scraped, Count: 242
# Page અઠવાડિયું scraped, Count: 243
# Page બુધવાર scraped, Count: 244
# Page મંગળવાર scraped, Count: 245
# Page ગુજરાતી scraped, Count: 246
# Page ગુજરાતી (સાપ્તાહિક) scraped, Count: 247
# Page ઇચ્છારામ દેસાઈ scraped, Count: 248
# Page ઔરંગઝેબ scraped, Count: 249
# Page અકબર scraped, Count: 250
# Page કંદહાર scraped, Count: 251
# Page કાબુલ scraped, Count: 252
# Page કાબુલ પ્રાંત scraped, Count: 253
# Page અફઘાની ભાષા scraped, Count: 254
# Page ઉર્દૂ scraped, Count: 255
# Page તુર્કિશ ભાષા scraped, Count: 256
# Page ઓસ્ટ્રિયા scraped, Count: 257
# Page ઇટાલી scraped, Count: 258
# Page આલ્બેનિયા scraped, Count: 259
# Page ઈટલી scraped, Count: 260
# Page એન્ડોરા scraped, Count: 261
# Page કઝાકિસ્તાન scraped, Count: 262
# Page ઉઝબેકિસ્તાન scraped, Count: 263
# Page ઈંડોનેશિયા scraped, Count: 264
# Page ઈઝરાયલ scraped, Count: 265
# Page ખ્રિસ્તી ધર્મ scraped, Count: 266
# Page ઇસુ scraped, Count: 267
# Page ઇઝરાયલ scraped, Count: 268
# Page જૉર્ડન scraped, Count: 269
# Page ઉત્તર કોરિયા scraped, Count: 270
# Page દક્ષિણ કોરિયા scraped, Count: 271
# Page એશિયાના દેશોની સૂચિ scraped, Count: 272
# Page ઓમાન scraped, Count: 273
# Page અરબી સમુદ્ર scraped, Count: 274
# Page કચ્છનો અખાત scraped, Count: 275
# Page કંડલા બંદર scraped, Count: 276
# Page અરબ સાગર scraped, Count: 277
# Page ખંભાતનો અખાત scraped, Count: 278
# Page ઉતાવળી નદી scraped, Count: 279
# Page અંબિકા નદી scraped, Count: 280
# Page અજરાઈ scraped, Count: 281
# Page આશ્રમશાળા scraped, Count: 282
# Page પ્રાથમિક શાળા scraped, Count: 283
# Page ઉચ્ચતર માધ્યમિક શાળા scraped, Count: 284
# Page માધ્યમિક શાળા scraped, Count: 285
# Page જિલ્લા પંચાયત scraped, Count: 286
# Page કેન્દ્રશાસિત પ્રદેશ scraped, Count: 287
# Page ઉત્તરાખંડ scraped, Count: 288
# Page અલકનંદા નદી scraped, Count: 289
# Page કર્ણ પ્રયાગ scraped, Count: 290
# Page ઋષિકેશ scraped, Count: 291
# Page કેદારનાથ scraped, Count: 292
# Page કેદારનાથ જ્યોતિર્લિંગ scraped, Count: 293
# Page ઓમકારેશ્વર scraped, Count: 294
# Page ઓમકારેશ્વર બંધ scraped, Count: 295
# Page ખંડવા જિલ્લો scraped, Count: 296
# Page અનૂપપુર જિલ્લો scraped, Count: 297
# Page અનૂપપુર scraped, Count: 298
# Page મધ્ય પ્રદેશ scraped, Count: 299
# Page અલીરાજપુર જિલ્લો scraped, Count: 300
# Page અશોકનગર જિલ્લો scraped, Count: 301
# Page અશોકનગર scraped, Count: 302
# Page ઇન્દૌર જિલ્લો scraped, Count: 303
# Page ઈંદોર scraped, Count: 304
# Page ઉજ્જૈન scraped, Count: 305
# Page ઉજ્જૈન જિલ્લો scraped, Count: 306
# Page ઉમરિયા જિલ્લો scraped, Count: 307
# Page ઉમરિયા scraped, Count: 308
# Page કટની જિલ્લો scraped, Count: 309
# Page કટની scraped, Count: 310
# Page ખરગોન જિલ્લો scraped, Count: 311
# Page ખરગોન scraped, Count: 312
# Page ગુના જિલ્લો scraped, Count: 313
# Page ગુના scraped, Count: 314
# Page ગ્વાલિયર જિલ્લો scraped, Count: 315
# Page ગ્વાલિયર scraped, Count: 316
# Page ભોપાલ scraped, Count: 317
# Page અગરતલા scraped, Count: 318
# Page ઇટાનગર scraped, Count: 319
# Page ઇમ્ફાલ scraped, Count: 320
# Page ઐઝવાલ scraped, Count: 321
# Page ઐઝવાલ જિલ્લો scraped, Count: 322
# Page કોલાસિબ જિલ્લો scraped, Count: 323
# Page કોલાસિબ scraped, Count: 324
# Page મિઝો ભાષા scraped, Count: 325
# Page ત્રિપુરા scraped, Count: 326
# Page કર્ણાટક scraped, Count: 327
# Page ઉડ્ડપી જિલ્લો scraped, Count: 328
# Page ઉડ્ડપી scraped, Count: 329
# Page ઉત્તર કન્નડ જિલ્લો scraped, Count: 330
# Page કારવાર scraped, Count: 331
# Page કોડાગુ જિલ્લો scraped, Count: 332
# Page કોપ્પલ જિલ્લો scraped, Count: 333
# Page કોપ્પલ scraped, Count: 334
# Page કોલાર જિલ્લો scraped, Count: 335
# Page કોલાર scraped, Count: 336
# Page ગડગ જિલ્લો scraped, Count: 337
# Page ગડગ scraped, Count: 338
# Page ગુલબર્ગ જિલ્લો scraped, Count: 339
# Page ગુલબર્ગ scraped, Count: 340
# Page ચામરાજનગર જિલ્લો scraped, Count: 341
# Page ચામરાજનગર scraped, Count: 342
# Page ચિકમંગલૂર જિલ્લો scraped, Count: 343
# Page ચિકમંગલુર scraped, Count: 344
# Page ચિક્કબલ્લાપુરા જિલ્લો scraped, Count: 345
# Page કન્નડ ભાષા scraped, Count: 346
# Page ચિત્રદુર્ગ જિલ્લો scraped, Count: 347
# Page ચિત્રદુર્ગ scraped, Count: 348
# Page તુમકુર જિલ્લો scraped, Count: 349
# Page તુમકુર scraped, Count: 350
# Page દક્ષિણ કન્નડ જિલ્લો scraped, Count: 351
# Page દાવનગિરી જિલ્લો scraped, Count: 352
# Page દાવનગિરી scraped, Count: 353
# Page ધારવાડ જિલ્લો scraped, Count: 354
# Page ધારવાડ scraped, Count: 355
# Page બગલકોટ જિલ્લો scraped, Count: 356
# Page પત્તાદકલ scraped, Count: 357
# Page ચાલુક્ય વંશ scraped, Count: 358
# Page મહારાષ્ટ્ર scraped, Count: 359
# Page અકોલા જિલ્લો scraped, Count: 360
# Page અકોલા scraped, Count: 361
# Page જિલ્લો scraped, Count: 362
# Page ગુજરાતના જિલ્લાઓ scraped, Count: 363
# Page અંજાર તાલુકો scraped, Count: 364
# Page અંજાર scraped, Count: 365
# Page અબડાસા તાલુકો scraped, Count: 366
# Page અરીખાણા (તા. અબડાસા) scraped, Count: 367
# Page આશાપર (તા. અબડાસા) scraped, Count: 368
# Page ઉકીર (તા. અબડાસા) scraped, Count: 369
# Page ઉસ્તીયા (તા. અબડાસા) scraped, Count: 370
# Page કચ્છ જિલ્લો scraped, Count: 371
# Page અમદાવાદ જિલ્લો scraped, Count: 372
# Page અમદાવાદ પશ્ચિમ લોક સભા મતવિસ્તાર scraped, Count: 373
# Page અમદાવાદ પૂર્વ લોક સભા મતવિસ્તાર scraped, Count: 374
# Page અલ્પેશ ઠાકોર scraped, Count: 375
# Page એંદલા (તા. સરસ્વતી) scraped, Count: 376
# Page કપાસ scraped, Count: 377
# Page ખેતી scraped, Count: 378
# Page ખળી scraped, Count: 379
# Page તમાકુ scraped, Count: 380
# Page દ્વિનામી નામકરણ scraped, Count: 381
# Page સ્વિડન scraped, Count: 382
# Page યુરોપ scraped, Count: 383
# Page આઇસલૅન્ડ scraped, Count: 384
# Page કોસોવો scraped, Count: 385
# Page ઉત્તર મેસિડોનિયા scraped, Count: 386
# Page ક્રોએશિયા scraped, Count: 387
# Page ગ્રીસ scraped, Count: 388
# Page જર્મની scraped, Count: 389
# Page જર્મન ભાષા scraped, Count: 390
# Page જિબ્રાલ્ટર scraped, Count: 391
# Page જ્યોર્જીયા (દેશ) scraped, Count: 392
# Page ઝેક ગણરાજ્ય scraped, Count: 393
# Page ડેન્માર્ક scraped, Count: 394
# Page નોર્વે scraped, Count: 395
# Page ઓસ્લો scraped, Count: 396
# Page તુર્કી scraped, Count: 397
# Page કતાર (અરબસ્તાન) scraped, Count: 398
# Page દોહા scraped, Count: 399
# Page શહેર scraped, Count: 400
# Page નગરપાલિકા scraped, Count: 401
# Page જાન્યુઆરી ૧ scraped, Count: 402
# Page અનંતરાય મણિશંકર રાવળ scraped, Count: 403
# Page અમરેલી scraped, Count: 404
# Page અમરેલી જિલ્લો scraped, Count: 405
# Page અમરેલી તાલુકો scraped, Count: 406
# Page અમરપુર વરૂડી (તા. અમરેલી) scraped, Count: 407
# Page આંકડીયા નાના (તા. અમરેલી) scraped, Count: 408
# Page ઇશ્વરીયા (તા. અમરેલી) scraped, Count: 409
# Page કમીગઢ (તા. અમરેલી) scraped, Count: 410
# Page કાઠમા (તા. અમરેલી) scraped, Count: 411
# Page કેરાળા (તા. અમરેલી) scraped, Count: 412
# Page ગુજરાતી ભાષા scraped, Count: 413
# Page અપભ્રંશ scraped, Count: 414
# Page સંસ્કૃત scraped, Count: 415
# Page કાશ્મીરી ભાષા scraped, Count: 416
# Page કાશ્મીર ખીણ scraped, Count: 417
# Page કારાકોરમ પર્વતમાળા scraped, Count: 418
# Page તાજિકિસ્તાન scraped, Count: 419
# Page કમ્બોડીયા scraped, Count: 420
# Page અંગકોર વાટ scraped, Count: 421
# Page કમ્બોડીયાનો રાષ્ટ્રધ્વજ scraped, Count: 422
# Page અફઘાનિસ્તાનનો રાષ્ટ્રધ્વજ scraped, Count: 423
# Page બૌદ્ધ ધર્મ scraped, Count: 424
# Page ગૌતમ બુદ્ધ scraped, Count: 425
# Page ત્રિપિટક scraped, Count: 426
# Page પાલિ ભાષા scraped, Count: 427
# Page બ્રાહ્મણ scraped, Count: 428
# Page ગાયત્રી scraped, Count: 429
# Page કમળ scraped, Count: 430
# Page ઇન્ડિયા ગેટ scraped, Count: 431
# Page ઈન્દિરા ગાંધી scraped, Count: 432
# Page અરુણા આસફ અલી scraped, Count: 433
# Page એમ. એસ. સુબ્બુલક્ષ્મી scraped, Count: 434
# Page એમ. જી. રામચંદ્રન scraped, Count: 435
# Page એમ. વિશ્વેશ્વરૈયા scraped, Count: 436
# Page ઇજનેરી મહાવિદ્યાલય, પુણે scraped, Count: 437
# Page ચેન્નઈ scraped, Count: 438
# Page ઈડલી scraped, Count: 439
# Page ગોઆ scraped, Count: 440
# Page આદિલ શાહી scraped, Count: 441
# Page બિજાપુર જિલ્લો scraped, Count: 442
# Page બિજાપુર scraped, Count: 443
# Page બિડાર જિલ્લો scraped, Count: 444
# Page બિડાર scraped, Count: 445
# Page બેંગલુરુ (ગ્રામીણ) જિલ્લો scraped, Count: 446
# Page બેંગલુરુ scraped, Count: 447
# Page ઇસરો scraped, Count: 448
# Page અવકાશ વિનિયોગ કેન્દ્ર scraped, Count: 449
# Page અમદાવાદ કલેક્ટર scraped, Count: 450
# Page અમદાવાદ કેન્ટોનમેન્ટ scraped, Count: 451
# Page અમદાવાદ બીઆરટીએસ scraped, Count: 452
# Page અમદાવાદ જનમાર્ગ સ્ટેશનોની યાદી scraped, Count: 453
# Page અમદાવાદ મેટ્રો scraped, Count: 454
# Page અમદાવાદ મ્યુનિસિપલ કોર્પોરેશન scraped, Count: 455
# Page અમદાવાદ મ્યુનિસિપલ ટ્રાન્સપોર્ટ સર્વિસ scraped, Count: 456
# Page અમદાવાદ રેલ્વે સ્ટેશન scraped, Count: 457
# Page અમદાવાદ શહેરી વિકાસ સત્તા મંડળ scraped, Count: 458
# Page અમદાવાદ શેર બજાર scraped, Count: 459
# Page અમદાવાદના દરવાજા scraped, Count: 460
# Page અમદાવાદની ગુફા scraped, Count: 461
# Page અમદાવાદની પોળોની યાદી scraped, Count: 462
# Page અમદાવાદની ભૂગોળ scraped, Count: 463
# Page અમદાવાદમાં શિક્ષણ scraped, Count: 464
# Page આંબલી (તા. દસ્ક્રોઇ) scraped, Count: 465
# Page અમદાવાદ સીટી (પશ્ચિમ) તાલુકો scraped, Count: 466
# Page અમદાવાદ સીટી (પૂર્વ) તાલુકો scraped, Count: 467
# Page અમદાવાદ સીટી તાલુકો scraped, Count: 468
# Page ગુજરાત સમાચાર scraped, Count: 469
# Page ધીરુભાઈ ઠાકર scraped, Count: 470
# Page ઊંચો પર્વત, ઊંડી ખીણ scraped, Count: 471
# Page અમર આશા scraped, Count: 472
# Page આત્મનિમજ્જન scraped, Count: 473
# Page આત્મવૃત્તાંત scraped, Count: 474
# Page અંબાલાલ પુરાણી scraped, Count: 475
# Page અંબુભાઈ પુરાણી પુરસ્કાર scraped, Count: 476
# Page અંજલિ ખાંડવાળા શ્રેષ્ઠ પ્રથમ વાર્તાસંગ્રહ પારિતોષિક scraped, Count: 477
# Page અંજલિ ખાંડવાળા scraped, Count: 478
# Page કિશોર જાદવ scraped, Count: 479
# Page આંબલીયારા (તા. ધોળકા) scraped, Count: 480
# Page અંધારી (તા. ધોળકા) scraped, Count: 481
# Page અરણેજ (તા. ધોળકા) scraped, Count: 482
# Page આંબારેલી (તા. ધોળકા) scraped, Count: 483
# Page આંભેઠી (તા. ધોળકા) scraped, Count: 484
# Page આનંદપુરા (તા. ધોળકા) scraped, Count: 485
# Page ઇંગોલી (તા. ધોળકા) scraped, Count: 486
# Page ઉતેળીયા (તા. ધોળકા) scraped, Count: 487
# Page કડીપુર (તા. ધોળકા) scraped, Count: 488
# Page કલ્યાણપુર (તા. ધોળકા) scraped, Count: 489
# Page કારીયાણા scraped, Count: 490
# Page કાળિયાપુરા (તા. ધોળકા) scraped, Count: 491
# Page કાવીઠા (તા. ધોળકા) scraped, Count: 492
# Page કેસરગઢ (તા. ધોળકા) scraped, Count: 493
# Page કોઠ (તા. ધોળકા) scraped, Count: 494
# Page કૌકા (તા. ધોળકા) scraped, Count: 495
# Page ખત્રીપુર (તા. ધોળકા) scraped, Count: 496
# Page ખરાંટી (તા. ધોળકા) scraped, Count: 497
# Page ખાનપુર (તા. ધોળકા) scraped, Count: 498
# Page ગણેસર (તા. ધોળકા) scraped, Count: 499
# Page ગણોલ (તા. ધોળકા) scraped, Count: 500
# Page ગિરંદ (તા. ધોળકા) scraped, Count: 501
# Page ગુંદી (તા. ધોળકા) scraped, Count: 502
# Page ચંડીસર (તા. ધોળકા) scraped, Count: 503
# Page ચલોડા (તા. ધોળકા) scraped, Count: 504
# Page જલાલપુર ગોધણેશ્વર scraped, Count: 505
# Page જલાલપુર વજીફા scraped, Count: 506
# Page જવારજ (તા. ધોળકા) scraped, Count: 507
# Page જાખડા (તા. ધોળકા) scraped, Count: 508
# Page ડડુસર (તા. ધોળકા) scraped, Count: 509
# Page તાલુકો scraped, Count: 510
# Page તાલુકા પંચાયત scraped, Count: 511
# Page તાલુકા વિકાસ અધિકારી scraped, Count: 512
# Page પંચાયતી રાજ scraped, Count: 513
# Page ઓમ બિરલા scraped, Count: 514
# Page કોટા scraped, Count: 515
# Page ઔરંગાબાદ scraped, Count: 516
# Page ઔરંગાબાદ જિલ્લો scraped, Count: 517
# Page અમરાવતી જિલ્લો scraped, Count: 518
# Page અમરાવતી scraped, Count: 519
# Page અહમદનગર જિલ્લો scraped, Count: 520
# Page અહમદનગર scraped, Count: 521
# Page મરાઠી ભાષા scraped, Count: 522
# Page કોંકણી ભાષા scraped, Count: 523
# Page ભારતની ભાષાઓની સૂચી scraped, Count: 524
# Page કેરળ scraped, Count: 525
# Page ઇડ્ડક્કિ જિલ્લો scraped, Count: 526
# Page ઇડ્ડક્કિ બંધ scraped, Count: 527
# Page એર્નાકુલમ જિલ્લો scraped, Count: 528
# Page એર્ણાકુલમ scraped, Count: 529
# Page એર્ણાકુલમ જીલ્લો scraped, Count: 530
# Page એલેપ્પી જિલ્લો scraped, Count: 531
# Page એલેપ્પી scraped, Count: 532
# Page પુરુષ scraped, Count: 533
# Page આર્યભટ્ટ scraped, Count: 534
# Page આર્યભટ્ટ (ઉપગ્રહ) scraped, Count: 535
# Page આઇ.આર.એસ. ઉપગ્રહ શ્રેણી scraped, Count: 536
# Page ઇન્સેટ ઉપગ્રહ શ્રેણી scraped, Count: 537
# Page ઉપગ્રહ પ્રક્ષેપણ યાન scraped, Count: 538
# Page એ.એસ.એલ.વી.યાન scraped, Count: 539
# Page એપલ (ઉપગ્રહ) scraped, Count: 540
# Page એસ્ટ્રોસેટ scraped, Count: 541
# Page કલ્પના-૧ scraped, Count: 542
# Page કલ્પના ચાવલા scraped, Count: 543
# Page ટેક્સસ scraped, Count: 544
# Page નાસા scraped, Count: 545
# Page જુલાઇ ૨૯ scraped, Count: 546
# Page આરીફ અલ્વી scraped, Count: 547
# Page ઇમરાન ખાન scraped, Count: 548
# Page પાકિસ્તાન scraped, Count: 549
# Page ઇસ્લામાબાદ scraped, Count: 550
# Page કરાચી scraped, Count: 551
# Page ઇન્ડોનેશિયા scraped, Count: 552
# Page કિર્ગિસ્તાન scraped, Count: 553
# Page ખ્રિસ્તી scraped, Count: 554
# Page યહૂદી ધર્મ scraped, Count: 555
# Page તૌરાત scraped, Count: 556
# Page મદદ:IPA/English scraped, Count: 557
# Page વિકિપીડિયા:Shortcut scraped, Count: 558
# Page વિકિપીડિયા:Administrators scraped, Count: 559
# Page વિકિપીડિયા:પ્રબંધક scraped, Count: 560
# Page વિકિપીડિયા:ઇન્ટરફેસ પ્રબંધકો scraped, Count: 561
# Page વિકિપીડિયા:ચોતરો scraped, Count: 562
# Page સભ્ય:Brihaspati scraped, Count: 563
# Page સભ્ય:Gazal world scraped, Count: 564
# Page બર્ટ્રાન્ડ રસેલ scraped, Count: 565
# Page ગણિત scraped, Count: 566
# Page GNU Free Documentation License scraped, Count: 567
# Page વિકિપીડિયા scraped, Count: 568
# Page જિમ્મી વેલ્સ scraped, Count: 569
# Page જુલાઇ ૮ scraped, Count: 570
# Page એપ્રિલ scraped, Count: 571
# Page એપ્રિલ ૧ scraped, Count: 572
# Page અબ્રાહમ મેસ્લો scraped, Count: 573
# Page કર્ટ ગોલ્ડસ્ટીન scraped, Count: 574
# Page પ્રથમ વિશ્વ યુદ્ધ scraped, Count: 575
# Page ફ્રાંસ scraped, Count: 576
# Page નેધરલેન્ડ scraped, Count: 577
# Page ખંડ scraped, Count: 578
# Page ઉત્તર અમેરિકા scraped, Count: 579
# Page એટલાન્ટીક મહાસાગર scraped, Count: 580
# Page ઉરુગ્વે scraped, Count: 581
# Page અરુબા scraped, Count: 582
# Page કેરેબિયન સાગર scraped, Count: 583
# Page પ્રશાંત મહાસાગર scraped, Count: 584
# Page એન્ટાર્કટીકા scraped, Count: 585
# Page વિકિમીડિયા કૉમન્સ scraped, Count: 586
# Page વિકિમીડિયા ફાઉન્ડેશન scraped, Count: 587
# Page ડોલર scraped, Count: 588
# Page વિકિકોશ scraped, Count: 589
# Page નવેમ્બર ૨૮ scraped, Count: 590
# Page ઈન્દુમતી ચીમનલાલ શેઠ scraped, Count: 591
# Page અંબાલાલ સારાભાઈ scraped, Count: 592
# Page ભારતનો સ્વાતંત્ર્ય સંગ્રામ scraped, Count: 593
# Some exception occured : 'pages'
# Page ઓલ ઈન્ડિયા મુસ્લિમ લીગ scraped, Count: 594
# Page ઢાકા scraped, Count: 595
# Page ચા scraped, Count: 596
# Page અજમો scraped, Count: 597
# Some exception occured : 'pages'
# Page ઉર્દુ scraped, Count: 598
# Page ફારસી ભાષા scraped, Count: 599
# Page આગ્રા કિલ્લો scraped, Count: 600
# Page તાજ મહલ scraped, Count: 601
# Page આગ્રાનો કિલ્લો scraped, Count: 602
# Page બાબર scraped, Count: 603
# Page ગુરુ ગોવિંદસિંહ scraped, Count: 604
# Page ખાલસા scraped, Count: 605
# Page માર્ચ ૩૦ scraped, Count: 606
# Page અલાસ્કા scraped, Count: 607
# Page રશિયા scraped, Count: 608
# Page પોર્ટુગલ scraped, Count: 609
# Page પોલેંડ scraped, Count: 610
# Page ફરો દ્વિપસમૂહ scraped, Count: 611
# Page ફીનલેંડ scraped, Count: 612
# Page ફ્રાન્સ scraped, Count: 613
# Page પૅરિસ scraped, Count: 614
# Page ચેમ્પ્સ-એલીસીસ (પેરિસ) scraped, Count: 615
# Page બલ્ગેરિયા scraped, Count: 616
# Page તુર્કસ્તાન scraped, Count: 617
# Page કુવૈત scraped, Count: 618
# Page રાજધાની scraped, Count: 619
# Page ગુપ્ત વંશ scraped, Count: 620
# Page કાલિદાસ scraped, Count: 621
# Page ગુપ્ત સામ્રાજ્ય scraped, Count: 622
# Page ચંદ્રગુપ્ત પ્રથમ scraped, Count: 623
# Page ગંગા નદી scraped, Count: 624
# Page ઉત્તરાંચલ scraped, Count: 625
# Page અલમોડા જિલ્લો scraped, Count: 626
# Page અલમોડા scraped, Count: 627
# Page અલમોડા જિલ્લા scraped, Count: 628
# Page ઉત્તરકાશી જિલ્લો scraped, Count: 629
# Page ઉત્તરકાશી scraped, Count: 630
# Page વસ્તી scraped, Count: 631
# Page ઔદ્યોગિક ક્રાંતિ scraped, Count: 632
# Page બીજું વિશ્વ યુદ્ધ scraped, Count: 633
# Page એડોલ્ફ હિટલર scraped, Count: 634
# Page એપ્રિલ ૨૦ scraped, Count: 635
# Page એપ્રિલ ૧૦ scraped, Count: 636
# Page એપ્રિલ ૧૧ scraped, Count: 637
# Page આલ્બર્ટ આઇનસ્ટાઇન scraped, Count: 638
# Page આઇન્સ્ટેનીયમ scraped, Count: 639
# Page અમેરિસીયમ scraped, Count: 640
# Page અર્ધધાતુ scraped, Count: 641
# Page આર્સેનિક scraped, Count: 642
# Page અર્બિયમ scraped, Count: 643
# Page આદર્શ વાયુ scraped, Count: 644
# Page જૂલ scraped, Count: 645
# Page જેમ્સ પ્રિસ્કોટ જૂલ scraped, Count: 646
# Page ભૌતિકવિજ્ઞાન scraped, Count: 647
# Page કુદરત scraped, Count: 648
# Page ગુરુત્વાકર્ષણ scraped, Count: 649
# Page દળ scraped, Count: 650
# Page પ્રકાશ scraped, Count: 651
# Page ફોટોન scraped, Count: 652
# Page આઇઝેક ન્યૂટન scraped, Count: 653
# Page આલ્બર્ટ આઇન્સ્ટાઇન scraped, Count: 654
# Page જવાહરલાલ નહેરુ scraped, Count: 655
# Page ઇન્દ્ર કુમાર ગુજરાલ scraped, Count: 656
# Page એપ્રિલ ૨૧ scraped, Count: 657
# Page એપ્રિલ ૧૨ scraped, Count: 658
# Page એપ્રિલ ૧૩ scraped, Count: 659
# Page એપ્રિલ ૧૪ scraped, Count: 660
# Page આંબેડકર જયંતિ scraped, Count: 661
# Page બાબાસાહેબ આંબેડકર scraped, Count: 662
# Page ઓક્ટોબર ૧૪ scraped, Count: 663
# Page એપ્રિલ ૧૬ scraped, Count: 664
# Page ઉલ્લાસકર દત્ત scraped, Count: 665
# Page કોલકાતા scraped, Count: 666
# Page ઉત્તર ૨૪ પરગણા જિલ્લો scraped, Count: 667
# Page ઉત્તર દિનાજપુર જિલ્લો scraped, Count: 668
# Page કૂચબિહાર જિલ્લો scraped, Count: 669
# Page કૂચબિહાર scraped, Count: 670
# Page પશ્ચિમ બંગાળ scraped, Count: 671
# Page કોલકોતા જિલ્લો scraped, Count: 672
# Page જલપાઈગુડી જિલ્લો scraped, Count: 673
# Page આદિવાસી scraped, Count: 674
# Page ઉચ્છલ scraped, Count: 675
# Page ઉચ્છલ તાલુકો scraped, Count: 676
# Page અભણકુવા scraped, Count: 677
# Page તાપી જિલ્લો scraped, Count: 678
# Page અમરસિંહ ચૌધરી scraped, Count: 679
# Page આનંદીબેન પટેલ scraped, Count: 680
# Page અમિત શાહ scraped, Count: 681
# Page ગુજરાત વિધાનસભા scraped, Count: 682
# Page અરવલ્લી જિલ્લો scraped, Count: 683
# Page અરવલ્લી scraped, Count: 684
# Page કચ્છનું રણ scraped, Count: 685
# Page કંકાવટી નદી scraped, Count: 686
# Page આજી નદી scraped, Count: 687
# Page આજી ડેમ scraped, Count: 688
# Page અણીયારા scraped, Count: 689
# Page આનંદપર (તા. રાજકોટ) scraped, Count: 690
# Page ઉમરાળી (તા. રાજકોટ) scraped, Count: 691
# Page કણકોટ (તા. રાજકોટ) scraped, Count: 692
# Page કસ્તુરબાધામ (ત્રંબા) (તા. રાજકોટ) scraped, Count: 693
# Page કસ્તુરબા scraped, Count: 694
# Page અરુણ મણિલાલ ગાંધી scraped, Count: 695
# Page અહિંસા scraped, Count: 696
# Page આંતરરાષ્ટ્રીય અહિંસા દિવસ scraped, Count: 697
# Page આગા ખાન મહેલ scraped, Count: 698
# Page આલ્ફ્રેડ હાઈસ્કૂલ (રાજકોટ) scraped, Count: 699
# Page ઇન્ડિયન ઓપિનિયન scraped, Count: 700
# Page ગુજરાત વિદ્યાપીઠ scraped, Count: 701
# Page અમદાવાદ યુનિર્વસિટી scraped, Count: 702
# Page આઇ.આઇ.એમ. અમદાવાદ scraped, Count: 703
# Page આંબાવાડી scraped, Count: 704
# Page ઇસનપુર, અમદાવાદ scraped, Count: 705
# Page ઉત્તર ઝોન, અમદાવાદ શહેર scraped, Count: 706
# Page ઉત્તર પશ્ચિમ ઝોન, અમદાવાદ શહેર scraped, Count: 707
# Page ઉસ્માનપુરા scraped, Count: 708
# Page એમ. જી. સાયન્સ કોલેજ scraped, Count: 709
# Page એલિસ બ્રિજ scraped, Count: 710
# Page કેવી રીતે જઈશ? (ચલચિત્ર‌‌) scraped, Count: 711
# Page અભિષેક જૈન scraped, Count: 712
# Page ઇન્ટરનેટ મૂવી ડેટાબેઝ scraped, Count: 713
# Page કેવી રીતે જઈશ (ચલચિત્ર) scraped, Count: 714
# Page ઐશ્વર્યા મજમુદાર scraped, Count: 715
# Page કેવી રીતે જઈશ? (ચલચિત્ર) scraped, Count: 716
# Page કાંકરિયા તળાવ scraped, Count: 717
# Page એલિસ બ્રિજ (વિસ્તાર) scraped, Count: 718
# Page અમદાવાદ ટાઉન હોલ scraped, Count: 719
# Page બી. વી. દોશી scraped, Count: 720
# Page જયપુર scraped, Count: 721
# Page કવરત્તી scraped, Count: 722
# Page કોહિમા scraped, Count: 723
# Page ગંગટોક scraped, Count: 724
# Page ગાંધીનગર scraped, Count: 725
# Page અક્ષરધામ (ગાંધીનગર) scraped, Count: 726
# Page ગાંધીનગર જિલ્લો scraped, Count: 727
# Page અંબાપુરની વાવ scraped, Count: 728
# Page આંબાપુર (તા. ગાંધીનગર) scraped, Count: 729
# Page અડાલજ scraped, Count: 730
# Page અડાલજની વાવ scraped, Count: 731
# Page અમૃતવર્ષીની વાવ scraped, Count: 732
# Page કર્ણમુક્તેશ્વર મહાદેવ, અમદાવાદ scraped, Count: 733
# Page કર્ણદેવ સોલંકી scraped, Count: 734
# Page આશાવલ scraped, Count: 735
# Page કાલુપુર scraped, Count: 736
# Page કેલિકો વસ્ત્ર સંગ્રહાલય scraped, Count: 737
# Page કોચરબ આશ્રમ scraped, Count: 738
# Page કાકા કાલેલકર scraped, Count: 739
# Page નિબંધ scraped, Count: 740
# Page પુરાણ scraped, Count: 741
# Page ઉપ પુરાણ scraped, Count: 742
# Page હિંદુ ધર્મ scraped, Count: 743
# Page કલિયુગ scraped, Count: 744
# Page દ્વાપરયુગ scraped, Count: 745
# Page કૃષ્ણ scraped, Count: 746
# Page ઉલૂપી scraped, Count: 747
# Page એકલવ્ય scraped, Count: 748
# Page કિંચક scraped, Count: 749
# Page કુંતી scraped, Count: 750
# Page ઇસ્કોન scraped, Count: 751
# Page ઇસ્કોન મંદિર scraped, Count: 752
# Page એ.સી. ભક્તિવેદાંત સ્વામી પ્રભુપાદ scraped, Count: 753
# Page ચૈતન્ય ચરિતામૃત scraped, Count: 754
# Page કૃષ્ણદાસ કવિરાજ scraped, Count: 755
# Page ચૈતન્ય મહાપ્રભુ scraped, Count: 756
# Page કિર્તન scraped, Count: 757
# Page અભિષેક scraped, Count: 758
# Page અશ્વમેધ scraped, Count: 759
# Page કૂવો scraped, Count: 760
# Page ચેન્નાઈ scraped, Count: 761
# Page એમ. એ. ચિદમ્બરમ સ્ટેડિયમ scraped, Count: 762
# Page યુવરાજસિંઘ scraped, Count: 763
# Page અક્ષય કુમાર scraped, Count: 764
# Page ઓમ શાંતિ ઓમ scraped, Count: 765
# Page અભિષેક બચ્ચન scraped, Count: 766
# Page અભિનેતા scraped, Count: 767
# Page અમિતાભ બચ્ચન scraped, Count: 768
# Page અમજદ ખાન scraped, Count: 769
# Page જુલાઇ ૨૭ scraped, Count: 770
# Page ઉદ્ધવ ઠાકરે scraped, Count: 771
# Page મહારાષ્ટ્રના મુખ્યમંત્રીઓ scraped, Count: 772
# Page ભાજપ scraped, Count: 773
# Page એકાત્મ માનવવાદ scraped, Count: 774
# Page આત્મા scraped, Count: 775
# Page જયપ્રકાશ નારાયણ scraped, Count: 776
# Page ઓક્ટોબર ૧૧ scraped, Count: 777
# Page એપ્રિલ ૧૭ scraped, Count: 778
# Page એપ્રિલ ૧૮ scraped, Count: 779
# Page એપ્રિલ ૧૯ scraped, Count: 780
# Page એપ્રિલ ૨ scraped, Count: 781
# Page એપ્રિલ ૨૨ scraped, Count: 782
# Page ઈમાન્યુએલ કાન્ટ scraped, Count: 783
# Page અનુભવવાદ scraped, Count: 784
# Page એરિસ્ટોટલ scraped, Count: 785
# Page Catharsis scraped, Count: 786
# Page પ્રાણીશાસ્ત્ર scraped, Count: 787
# Page જીવવિજ્ઞાન scraped, Count: 788
# Page દક્ષિણ એશિયા scraped, Count: 789
# Page અફઘાન અફઘાની scraped, Count: 790
# Page ઓડિયા ભાષા scraped, Count: 791
# Page છત્તીસગઢ scraped, Count: 792
# Page કવર્ધા જિલ્લો scraped, Count: 793
# Page કવર્ધા scraped, Count: 794
# Page કાંકેર જિલ્લો scraped, Count: 795
# Page કાંકેર scraped, Count: 796
# Page રાજ્ય scraped, Count: 797
# Page દેશ scraped, Count: 798
# Page ભારતનાં રાજ્યો અને કેન્દ્રશાસિત પ્રદેશો scraped, Count: 799
# Page કારગિલ scraped, Count: 800
# Page કારગિલ જિલ્લો scraped, Count: 801
# Page કારગિલ યુદ્ધ scraped, Count: 802
# Page પાકિસ્તાન ભૂમિસેના scraped, Count: 803
# Page સંયુક્ત રાષ્ટ્રસંઘ શાંતિસ્થાપના scraped, Count: 804
# Page ભારત સરકાર scraped, Count: 805
# Page દ્રૌપદી મુર્મૂ scraped, Count: 806
# Page જૂન ૨૦ scraped, Count: 807
# Page ઉનાળો scraped, Count: 808
# Page ચોમાસું scraped, Count: 809
# Page આસો scraped, Count: 810
# Page આસો વદ ૦)) scraped, Count: 811
# Page અષાઢ વદ ૦)) scraped, Count: 812
# Page અષાઢ વદ ૧ scraped, Count: 813
# Page અષાઢ વદ ૧૦ scraped, Count: 814
# Page અષાઢ વદ ૧૧ scraped, Count: 815
# Page અષાઢ વદ ૧૨ scraped, Count: 816
# Page અષાઢ વદ ૧૩ scraped, Count: 817
# Page અષાઢ વદ ૧૪ scraped, Count: 818
# Page અષાઢ વદ ૨ scraped, Count: 819
# Page અષાઢ વદ ૩ scraped, Count: 820
# Page અષાઢ વદ ૪ scraped, Count: 821
# Page અષાઢ વદ ૫ scraped, Count: 822
# Page અષાઢ વદ ૬ scraped, Count: 823
# Page અષાઢ વદ ૭ scraped, Count: 824
# Page અષાઢ વદ ૮ scraped, Count: 825
# Page અષાઢ વદ ૯ scraped, Count: 826
# Page અષાઢ સુદ ૧ scraped, Count: 827
# Page અષાઢ સુદ ૧૦ scraped, Count: 828
# Page અષાઢ સુદ ૧૧ scraped, Count: 829
# Page અષાઢ સુદ ૧૨ scraped, Count: 830
# Page અષાઢ સુદ ૧૩ scraped, Count: 831
# Page અષાઢ સુદ ૧૪ scraped, Count: 832
# Page અષાઢ સુદ ૨ scraped, Count: 833
# Page અષાઢ સુદ ૩ scraped, Count: 834
# Page અષાઢ સુદ ૪ scraped, Count: 835
# Page અષાઢ સુદ ૫ scraped, Count: 836
# Page અષાઢ સુદ ૬ scraped, Count: 837
# Page અષાઢ સુદ ૭ scraped, Count: 838
# Page અષાઢ સુદ ૮ scraped, Count: 839
# Page અષાઢ સુદ ૯ scraped, Count: 840
# Page આસો વદ ૧ scraped, Count: 841
# Page આસો વદ ૧૦ scraped, Count: 842
# Page આસો વદ ૧૧ scraped, Count: 843
# Page આસો વદ ૧૨ scraped, Count: 844
# Page આસો વદ ૧૩ scraped, Count: 845
# Page આસો વદ ૧૪ scraped, Count: 846
# Page આસો વદ ૨ scraped, Count: 847
# Page આસો વદ ૩ scraped, Count: 848
# Page આસો વદ ૪ scraped, Count: 849
# Page આસો વદ ૫ scraped, Count: 850
# Page આસો વદ ૬ scraped, Count: 851
# Page આસો વદ ૭ scraped, Count: 852
# Page આસો વદ ૮ scraped, Count: 853
# Page આસો વદ ૯ scraped, Count: 854
# Page આસો સુદ ૧ scraped, Count: 855
# Page આસો સુદ ૧૦ scraped, Count: 856
# Page આસો સુદ ૧૧ scraped, Count: 857
# Page આસો સુદ ૧૨ scraped, Count: 858
# Page આસો સુદ ૧૩ scraped, Count: 859
# Page આસો સુદ ૧૪ scraped, Count: 860
# Page આસો સુદ ૧૫ scraped, Count: 861
# Page આયંબિલ ઓળી scraped, Count: 862
# Page અણુવ્રત scraped, Count: 863
# Page અતિચાર scraped, Count: 864
# Page અનેકાંતવાદ scraped, Count: 865
# Page અપરિગ્રહ scraped, Count: 866
# Page અસ્તેય scraped, Count: 867
# Page આચાર્ય scraped, Count: 868
# Page સાધુ scraped, Count: 869
# Page આચાર્ય હરિભદ્ર scraped, Count: 870
# Page આવશ્યક સૂત્ર scraped, Count: 871
# Page ઋષભ દેવ scraped, Count: 872
# Page કર્મ scraped, Count: 873
# Page જૈન ધર્મ scraped, Count: 874
# Page કલ્પસૂત્ર scraped, Count: 875
# Page આચાર્ય ભદ્રબાહુ scraped, Count: 876
# Page મહાવીર સ્વામી scraped, Count: 877
# Page અરિહંત scraped, Count: 878
# Page તીર્થંકર scraped, Count: 879
# Page અજિતનાથ scraped, Count: 880
# Page કુમારપાળ scraped, Count: 881
# Page અજયપાળ scraped, Count: 882
# Page તેજપાળ scraped, Count: 883
# Page ગિરનાર scraped, Count: 884
# Page ઇડર scraped, Count: 885
# Page અરવિંદ ત્રિવેદી scraped, Count: 886
# Page ઉપેન્દ્ર ત્રિવેદી scraped, Count: 887
# Page કુકડીયા (તા. ઇડર) scraped, Count: 888
# Page ઇડર તાલુકો scraped, Count: 889
# Page અંકાલા (તા. ઇડર) scraped, Count: 890
# Page જીરુ scraped, Count: 891
# Page પાટણ જિલ્લો scraped, Count: 892
# Page આણંદ scraped, Count: 893
# Page અમૂલ scraped, Count: 894
# Page આઇસ્ક્રીમ scraped, Count: 895
# Page દૂધ scraped, Count: 896
# Page ગાય scraped, Count: 897
# Page તમિલનાડુ scraped, Count: 898
# Page અરિયાલુર scraped, Count: 899
# Page અરિયાલુર જિલ્લો scraped, Count: 900
# Page ઇરોડ જિલ્લો scraped, Count: 901
# Page ઇરોડ scraped, Count: 902
# Page કડ્ડલોર જિલ્લો scraped, Count: 903
# Page કડ્ડલોર scraped, Count: 904
# Page કન્યાકુમારી જિલ્લો scraped, Count: 905
# Page કરુર જિલ્લો scraped, Count: 906
# Page કરુર scraped, Count: 907
# Page કાચીપુરમ જિલ્લો scraped, Count: 908
# Page કાંચીપુરમ scraped, Count: 909
# Page કૃષ્ણાગિરિ જિલ્લો scraped, Count: 910
# Page કૃષ્ણાગિરિ scraped, Count: 911
# Page કેરી scraped, Count: 912
# Page આંબો scraped, Count: 913
# Page ગંગા scraped, Count: 914
# Page કર્મનાશા નદી scraped, Count: 915
# Page કૈમૂર જિલ્લો scraped, Count: 916
# Page અરરિયા જિલ્લો scraped, Count: 917
# Page અરરિયા scraped, Count: 918
# Page બિહાર scraped, Count: 919
# Page અરવલ જિલ્લો scraped, Count: 920
# Page અરવલ scraped, Count: 921
# Page ઔરંગાબાદ જિલ્લો (બિહાર) scraped, Count: 922
# Page ઔરંગાબાદ, બિહાર scraped, Count: 923
# Page ઔરંગાબાદ બિહાર scraped, Count: 924
# Page કટિહાર જિલ્લો scraped, Count: 925
# Page કટિહાર scraped, Count: 926
# Page કિશનગંજ જિલ્લો scraped, Count: 927
# Page કિશનગંજ scraped, Count: 928
# Page કોસી વિભાગ (પ્રમંડલ) scraped, Count: 929
# Page તિરહુત વિભાગ (પ્રમંડલ) scraped, Count: 930
# Page દરભંગા વિભાગ (પ્રમંડલ) scraped, Count: 931
# Page દરભંગા scraped, Count: 932
# Page દરભંગા જિલ્લા scraped, Count: 933
# Page ખગડિયા જિલ્લો scraped, Count: 934
# Page ગયા જિલ્લો scraped, Count: 935
# Page ગયા scraped, Count: 936
# Page ગોપાલગંજ જિલ્લો scraped, Count: 937
# Page ગોપાલગંજ scraped, Count: 938
# Page જમુઈ જિલ્લો scraped, Count: 939
# Page જમુઈ scraped, Count: 940
# Page જહાનાબાદ જિલ્લો scraped, Count: 941
# Page જહાનાબાદ scraped, Count: 942
# Page દરભંગા જિલ્લો scraped, Count: 943
# Page નવાદા જિલ્લો scraped, Count: 944
# Page નવાદા scraped, Count: 945
# Page નાલંદા જિલ્લો scraped, Count: 946
# Page પટણા જિલ્લો scraped, Count: 947
# Page પટણા વિભાગ (પ્રમંડલ) scraped, Count: 948
# Page પટના scraped, Count: 949
# Page કાનપુર scraped, Count: 950
# Page કાનપુર નગર જિલ્લો scraped, Count: 951
# Page આગ્રા પ્રાંત scraped, Count: 952
# Page અલ્હાબાદ પ્રાંત scraped, Count: 953
# Page આઝમગઢ પ્રાંત scraped, Count: 954
# Page આઝમગઢ જિલ્લો scraped, Count: 955
# Page આઝમગઢ scraped, Count: 956
# Page વારાણસી scraped, Count: 957
# Page કલ્કિ scraped, Count: 958
# Page ઘોડો scraped, Count: 959
# Page સિંહ scraped, Count: 960
# Page ઓક્ટોબર scraped, Count: 961
# Page એપ્રિલ ૨૩ scraped, Count: 962
# Page એપ્રિલ ૨૪ scraped, Count: 963
# Page એપ્રિલ ૨૫ scraped, Count: 964
# Page એપ્રિલ ૨૬ scraped, Count: 965
# Page એપ્રિલ ૨૭ scraped, Count: 966
# Page એપ્રિલ ૨૮ scraped, Count: 967
# Page એપ્રિલ ૨૯ scraped, Count: 968
# Page આંતરરાષ્ટ્રીય નૃત્ય દિવસ scraped, Count: 969
# Page આન્દ્રે અગાસી scraped, Count: 970
# Page અભિનેત્રી scraped, Count: 971
# Page બીબીસી scraped, Count: 972
# Page ટ્વિટર scraped, Count: 973
# Page બ્રિટીશ એશિયન scraped, Count: 974
# Page જાપાન scraped, Count: 975
# Page ક્યોટો scraped, Count: 976
# Page રાજાશાહી scraped, Count: 977
# Page સાર્વભૌમત્વ scraped, Count: 978
# Page ચીની ગણતંત્ર scraped, Count: 979
# Page નેધરલેંડ scraped, Count: 980
# Page સ્વતંત્રતા scraped, Count: 981
# Page દર્શન scraped, Count: 982
# Page આરતી scraped, Count: 983
# Page આસોપાલવ scraped, Count: 984
# Page જાકાર્તા scraped, Count: 985
# Page જાવા scraped, Count: 986
# Page OSI મોડેલ scraped, Count: 987
# Page PHP (પ્રોગ્રામિંગ ભાષા) scraped, Count: 988
# Page TCP/IP મોડેલ scraped, Count: 989
# Page ઇથરનેટ scraped, Count: 990
# Page ઈન્ટરનેટ પ્રોટોકોલ scraped, Count: 991
# Page ઈન્ટરનેટ પ્રોટોકોલ સ્યુટ scraped, Count: 992
# Page ઓપન શોર્ટેસ્ટ પાથ ફર્સ્ટ scraped, Count: 993
# Page કમ્પ્યુટર સુરક્ષા scraped, Count: 994
# Page કોમ્પ્યુટર scraped, Count: 995
# Page ઇમેજ સ્કેનર scraped, Count: 996
# Page USB ડ્રાઇવ scraped, Count: 997
# Page કમ્પ્યુટર પ્રિન્ટર scraped, Count: 998
# Page કમ્પ્યુટર મોનિટર scraped, Count: 999
# Page કોમ્પ્યુટર કીબોર્ડ scraped, Count: 1000
# Page કોમ્પ્યુટર માઉસ scraped, Count: 1001
# Page પોઇન્ટીંગ ઉપકરણ scraped, Count: 1002
# Page ફ્લોપી ડિસ્ક scraped, Count: 1003
# Page મધરબોર્ડ scraped, Count: 1004
# Page મેમરી કાર્ડ scraped, Count: 1005
# Page યુનિવર્સલ સીરિયલ બસ scraped, Count: 1006
# Page જાવા (પ્રોગ્રામિંગ ભાષા) scraped, Count: 1007
# Page PHP(પ્રોગ્રામિંગ ભાષા) scraped, Count: 1008
# Page કોમ્પ્યુટર નેટવર્ક scraped, Count: 1009
# Page કેમ્પર્સ નેટવર્ક scraped, Count: 1010
# Page કમ્પ્યુટર નેટવર્ક scraped, Count: 1011
# Page ગો (પ્રોગ્રામિંગ ભાષા) scraped, Count: 1012
# Page ગૂગલ scraped, Count: 1013
# Page Larry Page scraped, Count: 1014
# Page વર્લ્ડ વાઈડ વેબ scraped, Count: 1015
# Page ચાઇનીઝ ભાષા scraped, Count: 1016
# Page એશિયાઇ સિંહ scraped, Count: 1017
# Page ગીર અભયારણ્ય scraped, Count: 1018
# Page ઈંદ્રોડા પ્રકૃતિ શિક્ષણ અભયારણ્ય scraped, Count: 1019
# Page કચ્છ ઘોરાડ અભયારણ્ય scraped, Count: 1020
# Page કચ્છ રણ અભયારણ્ય scraped, Count: 1021
# Page અભયારણ્ય scraped, Count: 1022
# Page કર્નાલા પક્ષી અભયારણ્ય scraped, Count: 1023
# Page પૂણે scraped, Count: 1024
# Page ઇન્ટેલ કોર્પોરેશન scraped, Count: 1025
# Page મલેશિયા scraped, Count: 1026
# Page ઓગસ્ટ ૩૧ scraped, Count: 1027
# Page એપ્રિલ ૩ scraped, Count: 1028
# Page અમૃતલાલ પઢિયાર scraped, Count: 1029
# Page ચોરવાડ (તા. માળીયા હાટીના) scraped, Count: 1030
# Page અંબેચા (તા. માળીયા હાટીના) scraped, Count: 1031
# Page અકાળા(ગીર) (તા. માળીયા હાટીના) scraped, Count: 1032
# Page અકાળા (તા. માળીયા હાટીના) scraped, Count: 1033
# Page અમરાપુર(ગીર)(તા. માળીયા હાટીના) scraped, Count: 1034
# Page અવાણીયા (તા. માળીયા હાટીના) scraped, Count: 1035
# Page આંબલગઢ (તા. માળીયા હાટીના) scraped, Count: 1036
# Page આછીદ્રા (તા. માળીયા હાટીના) scraped, Count: 1037
# Page ઇટાળી (તા. માળીયા હાટીના) scraped, Count: 1038
# Page કડાયા (તા. માળીયા હાટીના) scraped, Count: 1039
# Page કત્રાસા (તા. માળીયા હાટીના) scraped, Count: 1040
# Page કાણેક (તા. માળીયા હાટીના) scraped, Count: 1041
# Page કાલીંભડા (તા. માળીયા હાટીના) scraped, Count: 1042
# Page કુકસવાડા (તા. માળીયા હાટીના) scraped, Count: 1043
# Page કેરાળા (તા. માળીયા હાટીના) scraped, Count: 1044
# Page કેશોદ તાલુકો scraped, Count: 1045
# Page અખોદડ (તા. કેશોદ) scraped, Count: 1046
# Page ચણા scraped, Count: 1047
# Page ઇથોપિયા scraped, Count: 1048
# Page અમ્હારિક ભાષા scraped, Count: 1049
# Page સ્વીડન scraped, Count: 1050
# Page સ્વીડિશ scraped, Count: 1051
# Page ચરબી scraped, Count: 1052
# Page ઘી scraped, Count: 1053
# Page નેપાળી scraped, Count: 1054
# Page નેપાળ scraped, Count: 1055
# Page અછામ જિલ્લો, નેપાળ scraped, Count: 1056
# Page અર્ઘખાંચી જિલ્લો, નેપાળ scraped, Count: 1057
# Page કંચનપુર જિલ્લો, નેપાળ scraped, Count: 1058
# Page કપિલવસ્તુ જિલ્લો, નેપાળ scraped, Count: 1059
# Page કર્ણાલી પ્રાંત (નેપાળ) scraped, Count: 1060
# Page કાઠમંડુ જિલ્લો, નેપાળ scraped, Count: 1061
# Page કાર્વેપાલનચોક જિલ્લો, નેપાળ scraped, Count: 1062
# Page કાલિકોટ જિલ્લો, નેપાળ scraped, Count: 1063
# Page કાસ્કી જિલ્લો, નેપાળ scraped, Count: 1064
# Page કૈલાલી જિલ્લો, નેપાળ scraped, Count: 1065
# Page કોસી પ્રાંત (નેપાળ) scraped, Count: 1066
# Page ગંડકી પ્રાંત (નેપાળ) scraped, Count: 1067
# Page ગુલ્મી જિલ્લો, નેપાળ scraped, Count: 1068
# Page ગોરખા જિલ્લો, નેપાળ scraped, Count: 1069
# Page જનકપુર પ્રાંત (નેપાળ) scraped, Count: 1070
# Page જનક scraped, Count: 1071
# Page અરુંધતી scraped, Count: 1072
# Page અષ્ટાવક્ર scraped, Count: 1073
# Page અહલ્યા scraped, Count: 1074
# Page ઇક્ષ્વાકુ વંશ scraped, Count: 1075
# Page ઇન્દ્રજીત scraped, Count: 1076
# Page ઉત્તરરામચરિત scraped, Count: 1077
# Page ઉમાશંકર જોશી scraped, Count: 1078
# Page અમૃતા પ્રીતમ scraped, Count: 1079
# Page કવિ scraped, Count: 1080
# Page નરસિંહ મહેતા scraped, Count: 1081
# Page કુંવરબાઈનું મામેરું scraped, Count: 1082
# Page વિકિસ્રોત scraped, Count: 1083
# Page પબ્લિક ડોમેન scraped, Count: 1084
# Page કલા scraped, Count: 1085
# Page કામસૂત્ર scraped, Count: 1086
# Page પત્ની scraped, Count: 1087
# Page લગ્ન scraped, Count: 1088
# Page તમિલ ભાષા scraped, Count: 1089
# Page પોંડિચેરી scraped, Count: 1090
# Page ચંડીગઢ scraped, Count: 1091
# Page કુન્નુર scraped, Count: 1092
# Page ઊટી scraped, Count: 1093
# Page ટીપુ સુલતાન scraped, Count: 1094
# Page બેંગલોર (ગ્રામીણ) જિલ્લો scraped, Count: 1095
# Page બેંગલુરુ (શહેરી) જિલ્લો scraped, Count: 1096
# Page બેલગામ જિલ્લો scraped, Count: 1097
# Page બેલગામ scraped, Count: 1098
# Page બેલ્લારી જિલ્લો scraped, Count: 1099
# Page બેલ્લારી scraped, Count: 1100
# Page રાયચૂર જિલ્લો scraped, Count: 1101
# Page માંડ્યા જિલ્લો scraped, Count: 1102
# Page માંડ્યા scraped, Count: 1103
# Page મૈસૂર જિલ્લો scraped, Count: 1104
# Page મૈસૂર scraped, Count: 1105
# Page રામનગર જિલ્લો scraped, Count: 1106
# Page શિમોગા જિલ્લો scraped, Count: 1107
# Page શિમોગા scraped, Count: 1108
# Page હસન જિલ્લો scraped, Count: 1109
# Page હાવેરી જિલ્લો scraped, Count: 1110
# Page હાવેરી scraped, Count: 1111
# Page ઢાંચો:કર્ણાટક રાજ્યના જિલ્લાઓ scraped, Count: 1112
# Page રાયચૂર scraped, Count: 1113
# Page તામિલ નાડુ scraped, Count: 1114
# Page ઉદગમંડલમ scraped, Count: 1115
# Page નિલગિરી જિલ્લો scraped, Count: 1116
# Page ઉટી scraped, Count: 1117
# Page નિલગીરી માઉન્ટેઇન રેલ્વે scraped, Count: 1118
# Page વિકિપીડિયા:સંદર્ભ scraped, Count: 1119
# Page વિકિપીડિયા:વિશ્વસનીય સ્રોતો ઓળખવા scraped, Count: 1120
# Page વિકિપીડિયા:"નિયમોને અવગણો"નો અર્થ scraped, Count: 1121
# Page સભ્યની ચર્ચા:KartikBot scraped, Count: 1122
# Page સભ્ય:KartikMistry scraped, Count: 1123
# Page ડેબિયન scraped, Count: 1124
# Page ઉબુન્ટુ (ઓપરેટિંગ સિસ્ટમ) scraped, Count: 1125
# Page બીયર scraped, Count: 1126
# Page આલ્કોહોલ scraped, Count: 1127
# Page ઈથિલીન scraped, Count: 1128
# Page ઈથર scraped, Count: 1129
# Page ઑક્સીજન scraped, Count: 1130
# Page આયોડિન scraped, Count: 1131
# Page આર્ગોન scraped, Count: 1132
# Page આવર્ત કોષ્ટક scraped, Count: 1133
# Page તત્વ scraped, Count: 1134
# Page ઈંડિયમ scraped, Count: 1135
# Page ઈટરબિયમ scraped, Count: 1136
# Page ઈટ્રીયમ scraped, Count: 1137
# Page ઈરિડીયમ scraped, Count: 1138
# Page એંટિમની scraped, Count: 1139
# Page એક્ટિનીયમ scraped, Count: 1140
# Page એલ્યુમિનિયમ scraped, Count: 1141
# Page એસ્ટાટીન scraped, Count: 1142
# Page ઓક્સીજન scraped, Count: 1143
# Page ઓસ્મીયમ scraped, Count: 1144
# Page કાર્બન scraped, Count: 1145
# Page કેડમિયમ scraped, Count: 1146
# Page કેલિફોર્નીયમ scraped, Count: 1147
# Page કેલ્શિયમ scraped, Count: 1148
# Page આલ્ક્લાઇન પાર્થિવ ધાતુ scraped, Count: 1149
# Page કોપરનિસીયમ scraped, Count: 1150
# Page કોબાલ્ટ scraped, Count: 1151
# Page ક્યુરીયમ scraped, Count: 1152
# Page ક્રિપ્ટોન scraped, Count: 1153
# Page ક્રોમિયમ scraped, Count: 1154
# Page ક્લોરિન scraped, Count: 1155
# Page ગેડોલિનીયમ scraped, Count: 1156
# Page ગેલિયમ scraped, Count: 1157
# Page ચાંદી scraped, Count: 1158
# Page ઉષ્મા scraped, Count: 1159
# Page તાપમાન scraped, Count: 1160
# Page કેલ્વિન scraped, Count: 1161
# Page એકમ scraped, Count: 1162
# Page ક્ષેત્રફળ scraped, Count: 1163
# Page ગોળો scraped, Count: 1164
# Page ચોરસ scraped, Count: 1165
# Page ત્રિકોણ scraped, Count: 1166
# Page ત્રિકોણમિતિ scraped, Count: 1167
# Page બહુકોણ scraped, Count: 1168
# Page આઇઝેક ન્યુટન scraped, Count: 1169
# Page ગતિના નિયમો scraped, Count: 1170
# Page ગુરૂત્વાકર્ષણ scraped, Count: 1171
# Page સર આઇઝેક ન્યુટન scraped, Count: 1172
# Page ચલ scraped, Count: 1173
# Page ન scraped, Count: 1174
# Page પરાવર્તિત ટેલીસ્કોપ scraped, Count: 1175
# Page પારો scraped, Count: 1176
# Page જર્મેનિયમ scraped, Count: 1177
# Page જસત scraped, Count: 1178
# Page ઝિર્કોનિયમ scraped, Count: 1179
# Page ઝેનોન scraped, Count: 1180
# Page ટંગસ્ટન scraped, Count: 1181
# Page ટર્બિયમ scraped, Count: 1182
# Page ટાઇટેનિયમ scraped, Count: 1183
# Page ટીન scraped, Count: 1184
# Page ટેક્નેશિયમ scraped, Count: 1185
# Page ટેન્ટેલમ scraped, Count: 1186
# Page ગ્રીસની પૌરાણિક માન્યતાઓ scraped, Count: 1187
# Page ઇલિયડ scraped, Count: 1188
# Page ગુજરાતી સાહિત્ય પરિષદ scraped, Count: 1189
# Page ગાંધીજી scraped, Count: 1190
# Page ઈલા ગાંધી scraped, Count: 1191
# Page એક હિંદુને એક પત્ર scraped, Count: 1192
# Page કનુ ગાંધી scraped, Count: 1193
# Page કનુ ગાંધી (વૈજ્ઞાનિક) scraped, Count: 1194
# Page કબા ગાંધીનો ડેલો scraped, Count: 1195
# Page કરમચંદ ઉત્તમચંદ ગાંધી scraped, Count: 1196
# Page કિશોરલાલ મશરૂવાળા scraped, Count: 1197
# Page ઓક્ટોબર ૫ scraped, Count: 1198
# Page અરવિંદ વેગડા scraped, Count: 1199
# Page ભારતીય જનતા પાર્ટી scraped, Count: 1200
# Page નરેન્દ્ર મોદી scraped, Count: 1201
# Page આમ આદમી પાર્ટી scraped, Count: 1202
# Page અણ્ણા હઝારે scraped, Count: 1203
# Page કિરણ બેદી scraped, Count: 1204
# Page સામાજિક વિજ્ઞાન scraped, Count: 1205
# Page મનોવિજ્ઞાન scraped, Count: 1206
# Page જે. બી. વોટસન scraped, Count: 1207
# Page વિજ્ઞાન scraped, Count: 1208
# Page ખગોળ શાસ્ત્ર scraped, Count: 1209
# Page બ્રહ્માંડ scraped, Count: 1210
# Page ઇમેન્યુએલ કેન્ટ scraped, Count: 1211
# Page ધરતીકંપ scraped, Count: 1212
# Page આગ scraped, Count: 1213
# Page પ્રાણવાયુ scraped, Count: 1214
# Page ટેલુરિયમ scraped, Count: 1215
# Page ગંધક scraped, Count: 1216
# Page ડાર્મસ્ટેડીયમ scraped, Count: 1217
# Page ડીસ્પ્રોસીયમ scraped, Count: 1218
# Page ડૂબનીયમ scraped, Count: 1219
# Page તાંબુ scraped, Count: 1220
# Page થુલિયમ scraped, Count: 1221
# Page થેલીયમ scraped, Count: 1222
# Page થોરીયમ scraped, Count: 1223
# Page નાઇટ્રોજન scraped, Count: 1224
# Page અણુ scraped, Count: 1225
# Page ઈલેક્ટ્રોન scraped, Count: 1226
# Page દ્રવ્યમાન scraped, Count: 1227
# Page ભૌતિક શાસ્ત્ર scraped, Count: 1228
# Page ગ્રીક મૂળાક્ષરો scraped, Count: 1229
# Page એ scraped, Count: 1230
# Page બળદ scraped, Count: 1231
# Page પાઇ scraped, Count: 1232
# Page શ્રીનિવાસ રામાનુજન scraped, Count: 1233
# Page અવિભાજ્ય સંખ્યા scraped, Count: 1234
# Page અવયવ scraped, Count: 1235
# Page ગૉડફ્રે હારૉલ્ડ હાર્ડિ scraped, Count: 1236
# Page અંકશાસ્ત્ર scraped, Count: 1237
# Page એસોટેરિક (અમુક વ્યક્તિઓ જ સમજી શકે તેવું) scraped, Count: 1238
# Page જ્યોતિષવિદ્યા scraped, Count: 1239
# Page અંકગણિત scraped, Count: 1240
# Page આર્કિમીડીઝ scraped, Count: 1241
# Page કોંગોનું પ્રજાસત્તાક ગણતંત્ર scraped, Count: 1242
# Page ટાન્ઝાનિયા scraped, Count: 1243
# Page કેન્યા scraped, Count: 1244
# Page ઇથિયોપિયા scraped, Count: 1245
# Page સુદાન scraped, Count: 1246
# Page નીલ નદી scraped, Count: 1247
# Page ખજૂર scraped, Count: 1248
# Page બાવળ scraped, Count: 1249
# Page હરિયાણા scraped, Count: 1250
# Page કુરુક્ષેત્ર scraped, Count: 1251
# Page કુરુ વંશ scraped, Count: 1252
# Page ક્ષત્રિય scraped, Count: 1253
# Page અદિતિ scraped, Count: 1254
# Page ઋષિ scraped, Count: 1255
# Page મહાભારત scraped, Count: 1256
# Page ઋષ્યશૃંગ scraped, Count: 1257
# Page અપ્સરા scraped, Count: 1258
# Page ઉર્વશી scraped, Count: 1259
# Page ચંદ્રવંશ scraped, Count: 1260
# Page કુરુક્ષેત્ર યુદ્ધ scraped, Count: 1261
# Page ઓક્ટોબર ૧૬ scraped, Count: 1262
# Page અવિનાશચંદ્ર ભટ્ટાચાર્ય scraped, Count: 1263
# Page ભારતીય સ્વતંત્રતા ચળવળ scraped, Count: 1264
# Page કણ્ણૂર scraped, Count: 1265
# Page કણ્ણૂર જિલ્લો scraped, Count: 1266
# Page અરાલમ વન્ય જીવ અભયારણ્ય scraped, Count: 1267
# Page મલયાલમ ભાષા scraped, Count: 1268
# ...
# Page પેપર (તા. થરાદ) scraped, Count: 14780
# Page પેપરાલ (તા. થરાદ) scraped, Count: 14781
# Page બુઢનપુર (તા. થરાદ) scraped, Count: 14782
# Page બેટલીયા (તા. થરાદ) scraped, Count: 14783
# Page બેવટા (તા. થરાદ) scraped, Count: 14784
# Page ભડોદર (તા. થરાદ) scraped, Count: 14785
# Page ભરડાસર (તા. થરાદ) scraped, Count: 14786
# Page ભલાસરા (તા. થરાદ) scraped, Count: 14787
# Page ભાચર (તા. થરાદ) scraped, Count: 14788
# Page ભાપડી (તા. થરાદ) scraped, Count: 14789
# Page ભાપી (તા. થરાદ) scraped, Count: 14790
# Page ભીમપુરા (તા. થરાદ) scraped, Count: 14791
# Page ભોરડુ (તા. થરાદ) scraped, Count: 14792
# Page ભોરોલ (તા. થરાદ) scraped, Count: 14793
# Page મડાલ (તા. થરાદ) scraped, Count: 14794
# Page મલુપુર (તા. થરાદ) scraped, Count: 14795
# Page મહાજનપુરા (તા. થરાદ) scraped, Count: 14796
# Page મહાદેવપુરા (તા. થરાદ) scraped, Count: 14797
# Page મિયાલ (તા. થરાદ) scraped, Count: 14798
# Page મેઘપુરા (તા. થરાદ) scraped, Count: 14799
# Page મેઢાળા (તા. થરાદ) scraped, Count: 14800
# Page મોટા મેસરા (તા. થરાદ) scraped, Count: 14801
# Page મોટી પાવડ (તા. થરાદ) scraped, Count: 14802
# Page મોરથલ (તા. થરાદ) scraped, Count: 14803
# Page મોરીલા (તા. થરાદ) scraped, Count: 14804
# Page રડકા (તા. થરાદ) scraped, Count: 14805
# Page રતનપુરા (તા. થરાદ) scraped, Count: 14806
# Page રાજકોટ (તા. થરાદ) scraped, Count: 14807
# Page રાણપુર (તા. થરાદ) scraped, Count: 14808
# Page રાણેસરી (તા. થરાદ) scraped, Count: 14809
# Page રામપુરા (તા. થરાદ) scraped, Count: 14810
# Page રાહ (તા. થરાદ) scraped, Count: 14811
# Page લખાપુરા (તા. થરાદ) scraped, Count: 14812
# Page લાલપુર (તા. થરાદ) scraped, Count: 14813
# Page લુણાલ (તા. થરાદ) scraped, Count: 14814
# Page લુણાવા (તા. થરાદ) scraped, Count: 14815
# Page લુવાણા(કળશ) (તા. થરાદ) scraped, Count: 14816
# Page લેંડાઉ (તા. થરાદ) scraped, Count: 14817
# Page લોઢનોર (તા. થરાદ) scraped, Count: 14818
# Page લોરવાડા (તા. થરાદ) scraped, Count: 14819
# Page વજેગઢ (તા. થરાદ) scraped, Count: 14820
# Page વડગામડા (તા. થરાદ) scraped, Count: 14821
# Page વળાદર (તા. થરાદ) scraped, Count: 14822
# Page વાંતડાઉ (તા. થરાદ) scraped, Count: 14823
# Page વાઘાસણ (તા. થરાદ) scraped, Count: 14824
# Page વામી (તા. થરાદ) scraped, Count: 14825
# Page વારા (તા. થરાદ) scraped, Count: 14826
# Page વેદલા (તા. થરાદ) scraped, Count: 14827
# Page શેરાઉ (તા. થરાદ) scraped, Count: 14828
# Page સણધર (તા. થરાદ) scraped, Count: 14829
# Page સણાવીયા (તા. થરાદ) scraped, Count: 14830
# Page સવપુરા (તા. થરાદ) scraped, Count: 14831
# Page સવરાખા (તા. થરાદ) scraped, Count: 14832
# Page સાબા (તા. થરાદ) scraped, Count: 14833
# Page સીધોતરા (તા. થરાદ) scraped, Count: 14834
# Page સેદલા (તા. થરાદ) scraped, Count: 14835
# Page હાથાવાડા (તા. થરાદ) scraped, Count: 14836
# Page અટાલ (તા. દાંતીવાડા) scraped, Count: 14837
# Page આકોલી (તા. દાંતીવાડા) scraped, Count: 14838
# Page આરખી (તા. દાંતીવાડા) scraped, Count: 14839
# Page ઓઢવા (તા. દાંતીવાડા) scraped, Count: 14840
# Page કોટડા જેગોલ (તા. દાંતીવાડા) scraped, Count: 14841
# Page ગણોદરા (તા. દાંતીવાડા) scraped, Count: 14842
# Page ગાંગુદરા (તા. દાંતીવાડા) scraped, Count: 14843
# Page ગાંગુવાડા (તા. દાંતીવાડા) scraped, Count: 14844
# Page ગુંદરી (તા. દાંતીવાડા) scraped, Count: 14845
# Page ગોઢ (તા. દાંતીવાડા) scraped, Count: 14846
# Page ચોડુંગરી (તા. દાંતીવાડા) scraped, Count: 14847
# Page જેગોલ (તા. દાંતીવાડા) scraped, Count: 14848
# Page જોરાપુરા ભાડલી (તા. દાંતીવાડા) scraped, Count: 14849
# Page જોરાપુરા લોડપા (તા. દાંતીવાડા) scraped, Count: 14850
# Page ઝાત (તા. દાંતીવાડા) scraped, Count: 14851
# Page ડાંગીયા (તા. દાંતીવાડા) scraped, Count: 14852
# Page ડેરી (તા. દાંતીવાડા) scraped, Count: 14853
# Page તાલેનગર (તા. દાંતીવાડા) scraped, Count: 14854
# Page ધનિયાવાડા (તા. દાંતીવાડા) scraped, Count: 14855
# Page ધાનેરી (તા. દાંતીવાડા) scraped, Count: 14856
# Page નાંદોત્રા ઠાકોરવાસ (તા. દાંતીવાડા) scraped, Count: 14857
# Page નાંદોત્રા બ્રાહ્મણવાસ (તા. દાંતીવાડા) scraped, Count: 14858
# Page નીલપુર (તા. દાંતીવાડા) scraped, Count: 14859
# Page પાંથાવાડા (તા. દાંતીવાડા) scraped, Count: 14860
# Page પાંસવાલ (તા. દાંતીવાડા) scraped, Count: 14861
# Page ફતેપુરા (તા. દાંતીવાડા) scraped, Count: 14862
# Page ભાંડોત્રા (તા. દાંતીવાડા) scraped, Count: 14863
# Page ભાકોદર (તા. દાંતીવાડા) scraped, Count: 14864
# Page ભાખર નાની (તા. દાંતીવાડા) scraped, Count: 14865
# Page ભાખર મોટી (તા. દાંતીવાડા) scraped, Count: 14866
# Page ભાડલી કોઠા (તા. દાંતીવાડા) scraped, Count: 14867
# Page ભાડલી ઝાત (તા. દાંતીવાડા) scraped, Count: 14868
# Page ભીલડા (તા. દાંતીવાડા) scraped, Count: 14869
# Page ભીલાચલ (તા. દાંતીવાડા) scraped, Count: 14870
# Page મહુડી નાની (તા. દાંતીવાડા) scraped, Count: 14871
# Page મહુડી મોટી (તા. દાંતીવાડા) scraped, Count: 14872
# Page મારવાડા (તા. દાંતીવાડા) scraped, Count: 14873
# Page માલપુરીયા (તા. દાંતીવાડા) scraped, Count: 14874
# Page રતનપુર (તા. દાંતીવાડા) scraped, Count: 14875
# Page રાજકોટ (તા. દાંતીવાડા) scraped, Count: 14876
# Page રાણોલ (તા. દાંતીવાડા) scraped, Count: 14877
# Page રામપુરા મહુડી (તા. દાંતીવાડા) scraped, Count: 14878
# Page રામસીડા છાપરા (તા. દાંતીવાડા) scraped, Count: 14879
# Page લાખણાસર (તા. દાંતીવાડા) scraped, Count: 14880
# Page લોડપા (તા. દાંતીવાડા) scraped, Count: 14881
# Page વડવાસ (તા. દાંતીવાડા) scraped, Count: 14882
# Page વાગોર (તા. દાંતીવાડા) scraped, Count: 14883
# Page વાઘરોલ (તા. દાંતીવાડા) scraped, Count: 14884
# Page વાવધરા (તા. દાંતીવાડા) scraped, Count: 14885
# Page વેલાવાસ (તા. દાંતીવાડા) scraped, Count: 14886
# Page શેરગઢ ઓધવા (તા. દાંતીવાડા) scraped, Count: 14887
# Page સાંતરવાડા (તા. દાંતીવાડા) scraped, Count: 14888
# Page સાતસણ (તા. દાંતીવાડા) scraped, Count: 14889
# Page સિકરીયા (તા. દાંતીવાડા) scraped, Count: 14890
# Page હરીયાવાડા (તા. દાંતીવાડા) scraped, Count: 14891
# Page ભાભર (બનાસકાંઠા) scraped, Count: 14892
# Page ઓગડપુરા (તા. દિયોદર) scraped, Count: 14893
# Page ઓઢા (તા. દિયોદર) scraped, Count: 14894
# Page કુંવાટા (તા. દિયોદર) scraped, Count: 14895
# Page કુંવાણા (તા. દિયોદર) scraped, Count: 14896
# Page કુંવારવા (તા. દિયોદર) scraped, Count: 14897
# Page કોટડા દિયોદર scraped, Count: 14898
# Page કોટડા ફોરણા (તા. દિયોદર) scraped, Count: 14899
# Page કોતરવાડા (તા. દિયોદર) scraped, Count: 14900
# Page ખણોદર (તા. દિયોદર) scraped, Count: 14901
# Page ગાંગોલ (તા. દિયોદર) scraped, Count: 14902
# Page ગોડા (તા. દિયોદર) scraped, Count: 14903
# Page ગોલવા (તા. દિયોદર) scraped, Count: 14904
# Page ગોલવી (તા. દિયોદર) scraped, Count: 14905
# Page ચગવાડા (તા. દિયોદર) scraped, Count: 14906
# Page ચમનપુરા (તા. દિયોદર) scraped, Count: 14907
# Page ચાવળા (તા. દિયોદર) scraped, Count: 14908
# Page ચીભડા (તા. દિયોદર) scraped, Count: 14909
# Page જડા (તા. દિયોદર) scraped, Count: 14910
# Page જલોધા (તા. દિયોદર) scraped, Count: 14911
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1376 try:
# -> 1377     response.begin()
#    1378 except ConnectionError:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1132 if buffer is not None:
# -> 1133     return self._sslobj.read(len, buffer)
#    1134 else:
#
# timeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/urllib3/connectionpool.py:369, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     368 if isinstance(err, SocketTimeout):
# --> 369     raise ReadTimeoutError(
#     370         self, url, f"Read timed out. (read timeout={timeout_value})"
#     371     ) from err
#     373 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='gu.wikipedia.org', port=443): Read timed out. (read timeout=10.0)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[3], line 95
#      92     print(f"Data has been saved to gujarati_wiki_scraped.csv")
#      94 # Call the function to scrape pages
# ---> 95 wikipedia_scrap()
#
# Cell In[3], line 90, in wikipedia_scrap()
#      87     scrape_page(start_page_title, writer)
#      89     # If recursion limit was reached, continue with iterative scraping
# ---> 90     scrape_page_iteratively(writer)
#      92 print(f"Data has been saved to gujarati_wiki_scraped.csv")
#
# Cell In[3], line 75, in wikipedia_scrap.<locals>.scrape_page_iteratively(writer)
#      72 print(f"Page {page_title} scraped, Count: {counter}")
#      74 # Add links from the current page to the queue
# ---> 75 for link_title in page.links.keys():
#      76     if link_title not in visited_links:
#      77         page_queue.append(link_title)
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/wikipediaapi/__init__.py:1012, in WikipediaPage.links(self)
#    1001 """
#    1002 Returns all pages linked from the current page.
#    1003
#    (...)
#    1009 :return: :class:`PagesDict`
#    1010 """
#    1011 if not self._called["links"]:
# -> 1012     self._fetch("links")
#    1013 return self._links
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/wikipediaapi/__init__.py:1065, in WikipediaPage._fetch(self, call)
#    1063 def _fetch(self, call) -> "WikipediaPage":
#    1064     """Fetches some data?."""
# -> 1065     getattr(self.wiki, call)(self)
#    1066     self._called[call] = True
#    1067     return self
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/wikipediaapi/__init__.py:403, in Wikipedia.links(self, page, **kwargs)
#     400 used_params = kwargs
#     401 used_params.update(params)
# --> 403 raw = self._query(page, used_params)
#     404 self._common_attributes(raw["query"], page)
#     405 pages = raw["query"]["pages"]
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/wikipediaapi/__init__.py:529, in Wikipedia._query(self, page, params)
#     527 params["format"] = "json"
#     528 params["redirects"] = 1
# --> 529 r = self._session.get(base_url, params=params, **self._request_kwargs)
#     530 return r.json()
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/requests/adapters.py:713, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     711     raise SSLError(e, request=request)
#     712 elif isinstance(e, ReadTimeoutError):
# --> 713     raise ReadTimeout(e, request=request)
#     714 elif isinstance(e, _InvalidHeader):
#     715     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='gu.wikipedia.org', port=443): Read timed out. (read timeout=10.0)
